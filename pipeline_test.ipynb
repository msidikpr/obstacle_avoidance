# %%
import sys
sys.path.insert(0, 'C:/Users/nlab/Documents/GitHub')
import warnings
warnings.filterwarnings('ignore')

# %%
from  obstacle_avoidance.obstacle_avoidance_processing import AvoidanceProcessing
# Out:
# Loading DLC 2.2.3...

# %%
import pandas as pd

# %%
# metadata json path
metadata_path = 'C:/Users/nlab/Desktop/mike_bonsai/recordings/metadata/oa_metadata.json'
#C:\Users\nlab\Desktop\mike_bonsai\recordings\metadata
# task name
# 'oa' for object avoidance
# 'gd' for gap detection
task_name = 'oa'

# %%
session = AvoidanceProcessing(metadata_path, task=task_name)
session.process()
# Out:
# 0it [00:00, ?it/s]
# 74
# df made
# saving092721_G6CK3RT_control_Rig2_oa
# 1it [00:13, 13.60s/it]

# %%
df =pd.read_hdf('C:/Users/nlab/Desktop/mike_bonsai/recordings/082522/G6CK3RT/oa/G6CK3RT_092721_oa.h5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 df =pd.read_hdf('C:/Users/nlab/Desktop/mike_bonsai/recordings/082522/G6CK3RT/oa/G6CK3RT_092721_oa.h5')
#
# File c:\Users\nlab\anaconda3\envs\ephys0\lib\site-packages\pandas\io\pytables.py:414, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     411     exists = False
#     413 if not exists:
# --> 414     raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     416 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     417 # can't auto open/close if we are using an iterator
#     418 # so delegate to the iterator
#
# FileNotFoundError: File C:/Users/nlab/Desktop/mike_bonsai/recordings/082522/G6CK3RT/oa/G6CK3RT_092721_oa.h5 does not exist

# %%
df
# Out:
#        first_poke   second_poke  \
# 2    38276.578905  38283.088115
# 4    38293.836531  38300.259929
# 5    38300.259929  38305.543923
# 6    38305.543923  38310.082585
# 7    38310.082585  38315.170252
# ..            ...           ...
# 142  38968.999232  38974.373401
# 143  38974.373401  38979.260275
# 144  38979.260275  38983.459072
# 145  38983.459072  38987.079961
# 147  38994.302016  38997.898508
#
#                                       trial_timestamps  \
# 2    [38276.587596, 38276.604313, 38276.621452, 382...
# 4    [38293.844275, 38293.861734, 38293.877619, 382...
# 5    [38300.263923, 38300.279052, 38300.295731, 383...
# 6    [38305.54839, 38305.56535, 38305.581056, 38305...
# 7    [38310.083212, 38310.098944, 38310.115712, 383...
# ..                                                 ...
# 142  [38969.005312, 38969.02208, 38969.039142, 3896...
# 143  [38974.374835, 38974.390771, 38974.407232, 389...
# 144  [38979.27648, 38979.29312, 38979.309824, 38979...
# 145  [38983.461158, 38983.47694, 38983.493734, 3898...
# 147  [38994.314137, 38994.330534, 38994.347366, 389...
#
#                                        trial_vidframes  \
# 2    [1873, 1874, 1875, 1876, 1877, 1878, 1879, 188...
# 4    [2908, 2909, 2910, 2911, 2912, 2913, 2914, 291...
# 5    [[3293, 3294, 3295, 3296, 3297, 3298, 3299, 33...
# 147  [474.8359069824219, 474.56768798828125, 474.38...
#
#                                              leftear_y  \
# 2    [196.46615600585938, 196.146240234375, 195.086...
# 4    [195.1338653564453, 194.52056884765625, 193.94...
# 5    [167.15252685546875, 167.37962341308594, 167.3...
# 6    [200.08175659179688, 199.99916076660156, 195.5...
# 7    [172.310546875, 172.84539794921875, 172.614852...
# ..                                                 ...
# 142  [195.73428344726562, 195.07199096679688, 194.3...
# 143  [171.63621520996094, 171.49986267089844, 170.8...
# 144  [193.55128479003906, 193.44235229492188, 193.0...
# 145  [169.89195251464844, 169.27276611328125, 169.0...
# 147  [171.17001342773438, 170.82498168945312, 171.3...
#
#                                     leftear_likelihood  ... bobstacle_x_std  \
# 2    [0.9999799728393555, 0.99997478723526, 0.99996...  ...             NaN
# 4    [0.9999699592590332, 0.9999597668647766, 0.999...  ...             NaN
# 5    [0.9997841119766235, 0.9997893571853638, 0.999...  ...             NaN
# 6    [0.9997133016586304, 0.9997833967208862, 0.999...  ...             NaN
# 7    [0.9994940757751465, 0.9994649291038513, 0.999...  ...             NaN
# ..                                                 ...  ...             ...
# 142  [0.9999502897262573, 0.9999438524246216, 0.999...  ...             NaN
# 143  [0.9998471736907959, 0.9998124837875366, 0.999...  ...             NaN
# 144  [0.9999386072158813, 0.9999310374259949, 0.999...  ...             NaN
# 145  [0.9998804330825806, 0.9998180866241455, 0.999...  ...             NaN
# 147  [0.9997843503952026, 0.9997037649154663, 0.999...  ...             NaN
#
#     bobstacle_y bobstacle_y_cm bobstacle_y_std wobstacle_x wobstacle_x_cm  \
# 2      4.355796       4.355796        0.058580    7.318591       7.318591
# 4      3.683537       3.683537        0.033724   22.747200      22.747200
# 5      9.698518       9.698518        4.494899   13.526145      13.526145
# 6     13.813188      13.813188        0.041169    7.157767       7.157767
# 7     13.941392      13.941392        0.113239   11.874644      11.874644
# ..          ...            ...             ...         ...            ...
# 142   14.177920      14.177920        0.047060   22.680433      22.680433
# 143   14.275330      14.275330        0.157457   19.465705      19.465705
# 144   14.440193      14.440193        0.022200   14.734269      14.734269
# 145   14.405521      14.405521        0.201370   11.367902      11.367902
# 147   14.480437      14.480437        0.089870    9.748287       9.748287
#
#     wobstacle_x_std wobstacle_y wobstacle_y_cm wobstacle_y_std
# 2          0.072424    4.355796       4.355796        0.058580
# 4          0.020117    3.683537       3.683537        0.033724
# 5          6.946422    9.698518       9.698518        4.494899
# 6          0.032935   13.813188      13.813188        0.041169
# 7          4.487034   13.941392      13.941392        0.113239
# ..              ...         ...            ...             ...
# 142        0.035432   14.177920      14.177920        0.047060
# 143        3.784580   14.275330      14.275330        0.157457
# 144        0.023793   14.440193      14.440193        0.022200
# 145        3.824107   14.405521      14.405521        0.201370
# 147        3.913470   14.480437      14.480437        0.089870
#
# [133 rows x 141 columns]

# %%
test = df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 test = df.head()
#
# NameError: name 'df' is not defined
